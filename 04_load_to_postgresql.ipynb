# %%
import pandas as pd
from sqlalchemy import create_engine

# Connect to PostgreSQL
# Replace 'yourpassword' with your actual PostgreSQL password
engine = create_engine('postgresql://postgres:9890209351@localhost:5432/olist_db')

# Load cleaned data
df  = pd.read_csv(r'C:\Users\ALG\OneDrive\Documents\olist-ecommerce-analysis\data\cleaned\olist_master.csv')
rfm = pd.read_csv(r'C:\Users\ALG\OneDrive\Documents\olist-ecommerce-analysis\data\cleaned\rfm_segments.csv')

# Push to PostgreSQL
df.to_sql('orders', engine, if_exists='replace', index=False)
print("✓ orders table loaded:", len(df), "rows")

rfm.to_sql('rfm_segments', engine, if_exists='replace', index=False)
print("✓ rfm_segments table loaded:", len(rfm), "rows")
# Out:
# ✓ orders table loaded: 96477 rows
# ✓ rfm_segments table loaded: 93357 rows
